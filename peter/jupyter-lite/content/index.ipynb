# %% [markdown]
# <table>
#   <tr>
#     <td><div align="left"><font size="30">ICRA 2026 Keynote Tutorial — Part 1 (Peter)</font></div></td>
#     <td><img src="https://raw.github.com/petercorke/robotics-toolbox-python/master/docs/figs/RobToolBox_RoundLogoB.png" width="200"></td>
#   </tr>
# </table>
#
# **Peter Corke** · Queensland University of Technology, The Useful Robot Company
#
# ---
#
# ## ⚠️  First time here? Pre-download everything now
#
# Run the cell at the bottom of the page, wait for the ✅, and you're ready for the session.
# This downloads ~240 MB of packages **once** and caches them in your browser.
#
# > Use the same browser and same profile on the day. Do **not** use incognito/private mode.
#
# ---
#
# ## 🔄 Returning before the session? Refresh your notebooks
#
# If the instructor has updated the notebooks since you pre-downloaded, use **File → Workspaces → Reset Workspace** to fetch the latest versions.
#
# ---
#
# ## Notebooks
#
# | | Notebook | Topic | Pre-download size |
# |---|---|---|---|
# | <img src="https://raw.githubusercontent.com/rai-opensource/spatialmath-python/master/docs/figs/CartesianSnakes_LogoW.png" width="50"> | [Spatial Math](spatial-math.ipynb) | Poses, transforms, trajectories | < 5 MB |
# | <img src="https://github.com/petercorke/machinevision-toolbox-python/raw/main/docs/figs/VisionToolboxLogo_NoBackgnd@2x.png?raw=1" width="50"> | [Machine Vision Toolbox](mvtb.ipynb) | Image processing, features, camera models | ~240 MB |
# | <img src="https://raw.githubusercontent.com/petercorke/robotics-toolbox-python/master/docs/figs/RobToolBox_RoundLogoB.png" width="50"> | [Robotics Toolbox](rtb.ipynb) | Mobile robotics, path planning, arm kinematics/dynamics | ~130 MB |
# | <img src="https://raw.githubusercontent.com/petercorke/bdsim/master/figs/BDSimLogo_NoBackgnd%402x.png" width="50"> | [Block Diagram Simulation](block-diagram.ipynb) | bdsim, control systems | ~130 MB |
#
#
# These notebooks run in your browser, zero manual install, using JupyterLite and web-assembly language (WASM).  An introduction to the technologies is [given here](https://blog.jupyter.org/jupyterlite-jupyter-%EF%B8%8F-webassembly-%EF%B8%8F-python-f6e2e41ab3fa).
# ---
#
# (c) Peter Corke 2026

# %%
# run this cell to load the Part 1 notebooks into your browser cache

import importlib
import setup_tutorial
importlib.reload(setup_tutorial)
await setup_tutorial.setup_tutorial(
    required_toolboxes=['roboticstoolbox', 'machinevisiontoolbox', 'bdsim'],
    required_packages=['matplotlib', 'numpy', 'scipy', 'opencv']
)
